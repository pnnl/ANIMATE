# %% [markdown]
# # LBNL59 Cases

# %% [markdown]
# ## Initalization

# %%
# Import auxiliary packages
import matplotlib.pyplot as plt
import json, six, glob, os

os.chdir('../../src')

# Import ANIMATE
from workflowsteps import *
from library import *
from libcases import *
from datetimeep import DateTimeEP

# %%
# Build verification items
items = assemble_verification_items(
    cases_path="../test_cases/lbnl59_cases/lbnl59_cases.json", 
    lib_items_path="../schema/library.json"
)
item = items[0]

# Run verification
try:
    plt.rcParams['figure.figsize'] = [16, 4 * 3]
    run_libcase(item, plot_option='all-expand')
except Exception as e:
    print(e)
# Out:
# =======
# dev_settings
# {'T_z_set_cool': 'zone_016_cooling_sp', 'T_z_set_heat': 'zone_016_heating_sp'}
# ===========
# Running case - ZoneTempControl
# ===========
# Verification results dict:
# {'Sample #': 137719, 'Pass #': 137719, 'Fail #': 0}

# %%
item = items[1]

# Run verification
try:
    plt.rcParams['figure.figsize'] = [16, 4 * 3]
    run_libcase(item, plot_option='all-expand')
except Exception as e:
    print(e)
# Out:
# =======
# dev_settings
# {'T_sa_set': 'rtu_001_sat_sp_tn'}
# =======
# parameters
# {'T_z_coo': 73}
# ===========
# Running case - SupplyAirTempReset
# ===========
# Verification results dict:
# {'Sample #': 1048575, 'Pass #': 1048575, 'Fail #': 0}
# Specific plot method implemented, additional distribution plot is being added!

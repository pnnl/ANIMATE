# %% [markdown]
# # Library verification show cases

# %% [markdown]
# ## Load framework and library

# %%
from workflowsteps import *
from library import *
from libcases import *
from datetimeep import DateTimeEP

import matplotlib.pyplot as plt

# plt.rcParams['figure.figsize'] = [16, 12]

# %% [markdown]
# ## Load and assemble verification items

# %%
cases_path = "../schema/library_verification_cases.json"
lib_items_path = "../schema/library.json"
items = assemble_verification_items(
    cases_path=cases_path, lib_items_path=lib_items_path
)

# %% [markdown]
# ### note: in flag plots, 1 -> pass, 0 -> fail

# %% [markdown]
# ### Integrated Economizer Control

# %%
items[0]
# Out:
# {'no': 1,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_RetailStandalone_STD2019_Seattle.csv'},
#  'datapoints_source': {'idf_output_variables': {'oa_flow': 'PSZ-AC:1_OAINLET NODE:System Node Standard Density Volume Flow Rate [m3/s](Each Call)',
#    'ccoil_out': 'PSZ-AC:1:Air System Cooling Coil Total Cooling Energy [J](Each Call)'},
#   'parameters': {'oa_min_flow': 0.23157}},
#  'verification_class': 'IntegratedEconomizerControl',
#  'library_item_id': 6,
#  'description_brief': 'Economizer shall be integrated with mechanical cooling',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 2]
run_libcase(items[0])
# Out:
# ...
# idf_output_variables
# {'oa_flow': 'PSZ-AC:1_OAINLET NODE:System Node Standard Density Volume Flow Rate [m3/s](Each Call)', 'ccoil_out': 'PSZ-AC:1:Air System Cooling Coil Total Cooling Energy [J](Each Call)'}
# ...
# parameters
# {'oa_min_flow': 0.23157}
# ...
# Running case - IntegratedEconomizerControl
# ...
# Verification results dict:
# {'Sample #': 70808, 'Pass #': 6767, 'Fail #': 64041}

# %% [markdown]
# ### Supply air temperature reset 2019

# %%
items[4]
# Out:
# {'no': 5,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_OfficeLarge_STD2019_Seattle.csv'},
#  'datapoints_source': {'idf_output_variables': {'T_sa_set': 'VAV_BOT WITH REHEAT SUPPLY EQUIPMENT OUTLET NODE:System Node Setpoint Temperature [C](Each Call)'},
#   'parameters': {'T_z_coo': 24.0}},
#  'verification_class': 'SupplyAirTempReset',
#  'library_item_id': 1,
#  'description_brief': 'Cooling supply air temperature reset scale (25%)',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 2]
run_libcase(items[4], plot_option="day-compact")
# Out:
# ...
# idf_output_variables
# {'T_sa_set': 'VAV_BOT WITH REHEAT SUPPLY EQUIPMENT OUTLET NODE:System Node Setpoint Temperature [C](Each Call)'}
# ...
# parameters
# {'T_z_coo': 24.0}
# ...
# Running case - SupplyAirTempReset
# ...
# Verification results dict:
# {'Sample #': 80215, 'Pass #': 80215, 'Fail #': 0}
# Specific plot method implemented, additional distribution plot is being added!

# %% [markdown]
# ### Supply air temperature reset 2004

# %%
items[13]
# Out:
# {'no': 14,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_OfficeLarge_STD2004_Seattle.csv'},
#  'datapoints_source': {'idf_output_variables': {'T_sa_set': 'VAV_BOT WITH REHEAT SUPPLY EQUIPMENT OUTLET NODE:System Node Setpoint Temperature [C](Each Call)'},
#   'parameters': {'T_z_coo': 24.0}},
#  'verification_class': 'SupplyAirTempReset',
#  'library_item_id': 1,
#  'description_brief': 'Cooling supply air temperature reset scale (25%)',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 2]
run_libcase(items[13], plot_option="day-compact")
# Out:
# ...
# idf_output_variables
# {'T_sa_set': 'VAV_BOT WITH REHEAT SUPPLY EQUIPMENT OUTLET NODE:System Node Setpoint Temperature [C](Each Call)'}
# ...
# parameters
# {'T_z_coo': 24.0}
# ...
# Running case - SupplyAirTempReset
# ...
# Verification results dict:
# {'Sample #': 156508, 'Pass #': 0, 'Fail #': 156508}
# Specific plot method implemented, additional distribution plot is being added!

# %% [markdown]
# ### Economizer High Limit A

# %%
items[5]
# Out:
# {'no': 6,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_RetailStandalone_STD2019_NewYork_a.csv'},
#  'datapoints_source': {'idf_output_variables': {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)',
#    'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)'},
#   'parameters': {'oa_min_flow': 0.23157, 'oa_threshold': 25.0}},
#  'verification_class': 'EconomizerHighLimitA',
#  'library_item_id': 2,
#  'description_brief': 'Fixed dry bulb economizer high limit',
#  'description_detail': 'Economizer needs to be OFF when High-Limit Condition was satisfied. Y_e_HL =f($Climate Zone, $Toa, $Tra, $hoa, $hra)',
#  'description_index': ['Table 6.5.1.1.3 in 90.1-2016'],
#  'description_datapoints': {'oa_db': 'OA dry bulb temperature',
#   'oa_threshold': 'OA dry bulb threshold',
#   'oa_min_flow': 'OA minimum airflow setpoint',
#   'oa_flow': 'OA airflow'},
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 5]
run_libcase(items[5], plot_option="all-expand")
# Out:
# ...
# idf_output_variables
# {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)', 'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)'}
# ...
# parameters
# {'oa_min_flow': 0.23157, 'oa_threshold': 25.0}
# ...
# Running case - EconomizerHighLimitA
# ...
# Verification results dict:
# {'Sample #': 52560, 'Pass #': 52560, 'Fail #': 0}

# %% [markdown]
# ### Economizer High Limit B

# %%
items[6]
# Out:
# {'no': 7,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_RetailStandalone_STD2019_NewYork_b.csv'},
#  'datapoints_source': {'idf_output_variables': {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)',
#    'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
#    'ret_a_temp': 'PSZ-AC:1 Supply Equipment Inlet Node:System Node Temperature [C](TimeStep)'},
#   'parameters': {'oa_min_flow': 0.23157}},
#  'verification_class': 'EconomizerHighLimitB',
#  'library_item_id': 3,
#  'description_brief': 'Differential dry bulb economizer high limit',
#  'description_detail': 'Check the 90.1-2016 table',
#  'description_index': ['Table 6.5.1.1.3 in 90.1-2016'],
#  'description_datapoints': {'oa_db': 'OA dry bulb temperature',
#   'ret_a_temp': 'Retuan air temperature',
#   'oa_min_flow': 'OA minimum airflow setpoint',
#   'oa_flow': 'OA airflow'},
# ...

# %%
run_libcase(items[6], plot_option="all-expand")
# Out:
# ...
# idf_output_variables
# {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)', 'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)', 'ret_a_temp': 'PSZ-AC:1 Supply Equipment Inlet Node:System Node Temperature [C](TimeStep)'}
# ...
# parameters
# {'oa_min_flow': 0.23157}
# ...
# Running case - EconomizerHighLimitB
# ...
# Verification results dict:
# {'Sample #': 52560, 'Pass #': 52560, 'Fail #': 0}

# %% [markdown]
# ### Economizer High Limit C

# %%
items[7]
# Out:
# {'no': 8,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_RetailStandalone_STD2019_NewYork_c.csv'},
#  'datapoints_source': {'idf_output_variables': {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)',
#    'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
#    'oa_enth': 'Environment:Site Outdoor Air Enthalpy [J/kg](TimeStep)'},
#   'parameters': {'oa_threshold': 25.0,
#    'oa_min_flow': 0.23157,
#    'oa_enth_threshold': 2600}},
#  'verification_class': 'EconomizerHighLimitC',
#  'library_item_id': 4,
#  'description_brief': 'Fixed enthalpy + fixed dry bulb economizer high limit',
#  'description_detail': 'N/A',
#  'description_index': ['Table 6.5.1.1.3 in 90.1-2016'],
#  'description_datapoints': {'oa_db': 'OA dry bulb temperature',
#   'oa_threshold': 'OA dry bulb threshold',
#   'oa_min_flow': 'OA minimum airflow setpoint',
#   'oa_flow': 'OA airflow',
#   'oa_enth': 'OA enthalpy',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 7]
run_libcase(items[7], plot_option="all-expand")
# Out:
# ...
# idf_output_variables
# {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)', 'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)', 'oa_enth': 'Environment:Site Outdoor Air Enthalpy [J/kg](TimeStep)'}
# ...
# parameters
# {'oa_threshold': 25.0, 'oa_min_flow': 0.23157, 'oa_enth_threshold': 2600}
# ...
# Running case - EconomizerHighLimitC
# ...
# Verification results dict:
# {'Sample #': 52560, 'Pass #': 52560, 'Fail #': 0}

# %% [markdown]
# ### Economizer High Limit D

# %%
items[8]
# Out:
# {'no': 9,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_RetailStandalone_STD2019_NewYork_d.csv'},
#  'datapoints_source': {'idf_output_variables': {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)',
#    'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
#    'ret_a_enth': 'PSZ-AC:1 SUPPLY EQUIPMENT INLET NODE:System Node Enthalpy [J/kg](TimeStep)',
#    'oa_enth': 'Environment:Site Outdoor Air Enthalpy [J/kg](TimeStep)'},
#   'parameters': {'oa_threshold': 25.0, 'oa_min_flow': 0.23157}},
#  'verification_class': 'EconomizerHighLimitD',
#  'library_item_id': 5,
#  'description_brief': 'Differential enthalpy + fixed dry bulb economizer high limit',
#  'description_detail': 'N/A',
#  'description_index': ['Table 6.5.1.1.3 in 90.1-2016'],
#  'description_datapoints': {'oa_db': 'OA dry bulb temperature',
#   'oa_threshold': 'OA dry bulb threshold',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 7]
run_libcase(items[8], plot_option="day-expand")
# Out:
# ...
# idf_output_variables
# {'oa_flow': 'PSZ-AC:1_OAInlet Node:System Node Standard Density Volume Flow Rate [m3/s](TimeStep)', 'oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)', 'ret_a_enth': 'PSZ-AC:1 SUPPLY EQUIPMENT INLET NODE:System Node Enthalpy [J/kg](TimeStep)', 'oa_enth': 'Environment:Site Outdoor Air Enthalpy [J/kg](TimeStep)'}
# ...
# parameters
# {'oa_threshold': 25.0, 'oa_min_flow': 0.23157}
# ...
# Running case - EconomizerHighLimitD
# ...
# Verification results dict:
# {'Sample #': 52560, 'Pass #': 52557, 'Fail #': 3}

# %% [markdown]
# ### Zone Temperature Control

# %%
items[9]
# Out:
# {'no': 10,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_RetailStandalone_STD2019_NewYork_zonetempctrl.csv'},
#  'datapoints_source': {'idf_output_variables': {'T_z_set_cool': 'CORE_RETAIL:Zone Thermostat Cooling Setpoint Temperature [C](Each Call)',
#    'T_z_set_heat': 'CORE_RETAIL:Zone Thermostat Heating Setpoint Temperature [C](Each Call)'}},
#  'verification_class': 'ZoneTempControl',
#  'library_item_id': 8,
#  'description_brief': 'Zone temperature setpoint deadband >= 5F (2.77C)',
#  'description_detail': 'Where used to control both heating and cooling, zone thermostatic controls shall be capable of and configured to provide a temperature range or dead band of at least 5Â°F within which the supply of heating and cooling energy to the zone is shut off or reduced to a minimum.',
#  'description_index': ['Section 6.4.3.1.2 in 90.1-2016'],
#  'description_datapoints': {'T_z_set_cool': 'Zone cooling temperature setpoint',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 2]
run_libcase(items[9])
# Out:
# ...
# idf_output_variables
# {'T_z_set_cool': 'CORE_RETAIL:Zone Thermostat Cooling Setpoint Temperature [C](Each Call)', 'T_z_set_heat': 'CORE_RETAIL:Zone Thermostat Heating Setpoint Temperature [C](Each Call)'}
# ...
# Running case - ZoneTempControl
# ...
# Verification results dict:
# {'Sample #': 70847, 'Pass #': 70847, 'Fail #': 0}

# %% [markdown]
# ### HW Reset

# %%
items[10]
# Out:
# {'no': 11,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_Hospital_STD2019_Atlanta.csv'},
#  'datapoints_source': {'idf_output_variables': {'T_oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
#    'T_hw': 'HeatSys1 Supply Outlet Node:System Node Temperature [C](TimeStep)',
#    'm_hw': 'HeatSys1 Supply Outlet Node:System Node Mass Flow Rate [kg/s](TimeStep)'},
#   'parameters': {'T_oa_max': 10,
#    'T_oa_min': -6.7,
#    'T_hw_max_st': 60.0,
#    'T_hw_min_st': 48.89}},
#  'verification_class': 'HWReset',
#  'library_item_id': 9,
#  'description_brief': 'Hot water supply water temperature reset',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 8]
run_libcase(items[10], plot_option="all-expand")
# Out:
# ...
# idf_output_variables
# {'T_oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)', 'T_hw': 'HeatSys1 Supply Outlet Node:System Node Temperature [C](TimeStep)', 'm_hw': 'HeatSys1 Supply Outlet Node:System Node Mass Flow Rate [kg/s](TimeStep)'}
# ...
# parameters
# {'T_oa_max': 10, 'T_oa_min': -6.7, 'T_hw_max_st': 60.0, 'T_hw_min_st': 48.89}
# ...
# Running case - HWReset
# ...
# Verification results dict:
# {'Sample #': 52560, 'Pass #': 52526, 'Fail #': 34}

# %% [markdown]
# ### CHW Reset

# %%
items[11]
# Out:
# {'no': 12,
#  'run_simulation': False,
#  'simulation_IO': {'output': 'ASHRAE901_Hospital_STD2019_Atlanta.csv'},
#  'datapoints_source': {'idf_output_variables': {'T_oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
#    'T_chw': 'CoolSys1 Supply Outlet Node:System Node Temperature [C](TimeStep)',
#    'm_chw': 'CoolSys1 Supply Outlet Node:System Node Mass Flow Rate [kg/s](TimeStep)'},
#   'parameters': {'T_oa_max': 21.11,
#    'T_oa_min': 12.78,
#    'T_chw_max_st': 8.89,
#    'T_chw_min_st': 6.7}},
#  'verification_class': 'CHWReset',
#  'library_item_id': 10,
#  'description_brief': 'Chilled water supply water temperature reset',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 8]
run_libcase(items[11], plot_option="day-expand")
# Out:
# ...
# idf_output_variables
# {'T_oa_db': 'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)', 'T_chw': 'CoolSys1 Supply Outlet Node:System Node Temperature [C](TimeStep)', 'm_chw': 'CoolSys1 Supply Outlet Node:System Node Mass Flow Rate [kg/s](TimeStep)'}
# ...
# parameters
# {'T_oa_max': 21.11, 'T_oa_min': 12.78, 'T_chw_max_st': 8.89, 'T_chw_min_st': 6.7}
# ...
# Running case - CHWReset
# ...
# Verification results dict:
# {'Sample #': 52560, 'Pass #': 34647, 'Fail #': 17913}

# %% [markdown]
# ### Integrated Economizer Control (with IDF instrumentation and EnergyPlus simulation)

# %%
items[12]
# Out:
# {'no': 13,
#  'run_simulation': True,
#  'simulation_IO': {'idf': '../resources/ASHRAE901_RetailStandalone_STD2019_Seattle.idf',
#   'idd': '../resources/Energy+V9_0_1.idd',
#   'weather': '../weather/USA_WA_Seattle-Tacoma.Intl.AP.727930_TMY3.epw',
#   'output': 'eplusout.csv'},
#  'datapoints_source': {'idf_objects': {'oa_min_flow': {'filters': {'idf_object_type': 'Controller:OutdoorAir',
#      'Name': 'PSZ-AC:1_OA_Controller'},
#     'field': 'Minimum_Outdoor_Air_Flow_Rate'}},
#   'idf_output_variables': {'oa_flow': {'subject': 'PSZ-AC:1_OAINLET NODE',
#     'variable': 'System Node Standard Density Volume Flow Rate',
#     'frequency': 'detailed'},
#    'ccoil_out': {'subject': 'PSZ-AC:1',
#     'variable': 'Air System Cooling Coil Total Cooling Energy',
#     'frequency': 'detailed'}}},
#  'verification_class': 'IntegratedEconomizerControl',
#  'library_item_id': 6,
#  'description_brief': 'Economizer shall be integrated with mechanical cooling',
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 4 * 3]
run_libcase(items[12], plot_option="day-compact")
# Out:
# ...
# idf_objects
# {'oa_min_flow': {'filters': {'idf_object_type': 'Controller:OutdoorAir', 'Name': 'PSZ-AC:1_OA_Controller'}, 'field': 'Minimum_Outdoor_Air_Flow_Rate'}}
# ...
# idf_output_variables
# {'oa_flow': {'subject': 'PSZ-AC:1_OAINLET NODE', 'variable': 'System Node Standard Density Volume Flow Rate', 'frequency': 'detailed'}, 'ccoil_out': {'subject': 'PSZ-AC:1', 'variable': 'Air System Cooling Coil Total Cooling Energy', 'frequency': 'detailed'}}
# ...
# Running case - IntegratedEconomizerControl
# ...
# Running simulation: ../resources/ASHRAE901_RetailStandalone_STD2019_Seattle_injected.idf -- 2021-07-21 14:51:11.361085
# Simulation complete -- 2021-07-21 14:51:56.234083
# Simulation log saved to output folder -- 2021-07-21 14:51:56.237084
# simulation done
# Verification results dict:
# {'Sample #': 70808, 'Pass #': 6767, 'Fail #': 64041}
